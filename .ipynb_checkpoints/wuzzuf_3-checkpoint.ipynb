# %%
import pandas as pd 
from bs4 import BeautifulSoup 
import requests

# %%
result=requests.get('https://wuzzuf.net/search/jobs/?a=navbg&q=data%20analyst&start=')  
src=result.content 
soup=BeautifulSoup(src,"lxml")

# %%
job_title=soup.find_all("h2",{"class":"css-m604qf"}) 
company_name=soup.find_all("a",{"class":"css-17s97q8"})
company_location=soup.find_all("span",{"class":"css-5wys0k"})
job_skills=soup.find_all('div', attrs={'class': None})
job_nature=soup.find_all("span",{"class":"css-1ve4b75 eoyjyou0"})

# %%
titles=[] 
names=[]
locations=[] 
nature=[]
skills=[]

# %%
for i in range(len(job_title)) : 
    titles.append(job_title[i].text) 
    names.append(company_name[i].text)
    locations.append(company_location[i].text)
    nature.append(job_nature[i].text)

# %%
for i in range(6,21) : 
      skills.append(job_skills[i].text)

# %%
for i in range(10) : 
    result=requests.get(f'https://wuzzuf.net/search/jobs/?a=navbg&q=data%20analyst&start={i}')  
    src=result.content 
    soup=BeautifulSoup(src,"lxml")
    job_title=soup.find_all("h2",{"class":"css-m604qf"}) 
    company_name=soup.find_all("a",{"class":"css-17s97q8"})
    company_location=soup.find_all("span",{"class":"css-5wys0k"})
    job_skills=soup.find_all('div', attrs={'class': None})
    job_nature=soup.find_all("span",{"class":"css-1ve4b75 eoyjyou0"}) 
    
    for i in range(len(job_title)) : 
        titles.append(job_title[i].text) 
        names.append(company_name[i].text)
        locations.append(company_location[i].text)
        nature.append(job_nature[i].text)
    
    for i in range(6,21) : 
        skills.append(job_skills[i].text)

# %%
wuzzuf={'job_title':titles,'company_name':names,'company_location':locations,'job_nature':nature,'job_skills':skills}

# %%
wuzzuf=pd.DataFrame(wuzzuf)

# %%
wuzzuf
# Out:
#                                              job_title  \
# 0                                  Export Data Analyst
# 1                                    Risk Data Analyst
# 2                                         Data Analyst
# 3                                         Data Analyst
# 4                                 Data Quality Analyst
# ..                                                 ...
# 160                               MERN Stack Developer
# 161  Marketing Specialist (Digital Marketing & Soci...
# 162                  ERP Finance Functional Consultant
# 163                              Senior Java Developer
# 164         Financial Planning & Analysis Section Head
#
#                                           company_name  \
# 0                                        Evyap Egypt -
# 1                                Fawry Microfinance  -
# 2    The Address Investments for Real Estate Consul...
# 3          The Egyptian Microfinance Company- Maksab -
# 4    The Address Investments for Real Estate Consul...
# ..                                                 ...
# 160                                     Confidential -
# 161                                    NCC X-calibur -
# 162                               Seoudi Supermarket -
# 163                                       FlairsTech -
# 164                                     Confidential -
#
#                  company_location job_nature  \
# 0         Sheraton, Cairo, Egypt   Full Time
# 1            Maadi, Cairo, Egypt   Full Time
# 2        New Cairo, Cairo, Egypt   Full Time
# 3        New Cairo, Cairo, Egypt   Full Time
# 4        New Cairo, Cairo, Egypt   Full Time
# ..                            ...        ...
# 160                 Cairo, Egypt   Full Time
# 161      New Cairo, Cairo, Egypt   Full Time
# 162  6th of October, Giza, Egypt   Full Time
# 163          Maadi, Cairo, Egypt   Full Time
# 164     Mohandessin, Giza, Egypt   Full Time
#
#                                             job_skills
# 0    Experienced · 3 - 5 Yrs of Exp · Sales/Retail ...
# 1    Entry Level · 0 - 2 Yrs of Exp · Analyst/Resea...
# 2    Experienced · 2 - 5 Yrs of Exp · IT/Software D...
# 3    Experienced · 1 - 3 Yrs of Exp · Accounting/Fi...
# 4    Experienced · 1 - 3 Yrs of Exp · IT/Software D...
# ..                                                 ...
# 160  Experienced · 5 - 9 Yrs of Exp · IT/Software D...
# 161  Experienced · 3 - 5 Yrs of Exp · Marketing/PR/...
# 162  Manager · 5 - 7 Yrs of Exp · Accounting/Financ...
# 163  Experienced · 3 - 9 Yrs of Exp · IT/Software D...
# 164  Experienced · 7 - 10 Yrs of Exp · Accounting/F...
#
# [165 rows x 5 columns]

# %%
WUZZUF=pd.read_csv('wuzzuf.csv')

# %%
WUZZUF=pd.concat([wuzzuf,WUZZUF],axis=0)

# %%
WUZZUF.shape
# Out:
# (180, 5)

# %%
WUZZUF.tail(15)
# Out:
#                                             job_title  \
# 0   DATA ENGINEER (DATA SCIENTIST) -NCR (REMOTE) (...
# 1            Data Scientist/ Analyst- Remote - Urgent
# 2                                      Data Scientist
# 3                               Senior Data Scientist
# 4                                      Data Scientist
# 5                immunology/immuno-oncology scientist
# 6                        Business Analyst "Data & AI"
# 7                        Data Science Software Intern
# 8                         Product Manager & Team Lead
# 9                            Senior AI & NLP Engineer
# 10                    Senior Data Management Engineer
# 11                     Full Stack Developer - Laravel
# 12                                 Power BI Developer
# 13                               Full Stack Developer
# 14       Senior Full Stack Developer (.NET & Angular)
#
#                                    company_name  \
# 0                                     Pillars -
# 1                            GetTechForce.com -
# 2                                Confidential -
# 3                                Confidential -
# 4                          Seoudi Supermarket -
# 5                                   Proteinea -
# 6                               Global Brands -
# 7                            Sequel Solutions -
# 8                                   Genify.ai -
# 9                                Eg Insurtech -
# 10                                     Ejada  -
# 11                             Visit Ventures -
# 12                                 Duravit AG -
# 13  The Egyptian Microfinance Company- Maksab -
# 14                                 FlairsTech -
#
#                        company_location               job_nature  \
# 0                         Cairo, Egypt                 Full Time
# 1                         Cairo, Egypt   Full TimeWork From Home
# 2                          Giza, Egypt                 Full Time
# 3              New Nozha, Cairo, Egypt                 Full Time
# 4            Sheikh Zayed, Giza, Egypt                 Full Time
# 5                         Cairo, Egypt                 Full Time
# 6              New Cairo, Cairo, Egypt                 Full Time
# 7                         Cairo, Egypt                Internship
# 8                         Cairo, Egypt                 Full Time
# 9                         Cairo, Egypt                 Full Time
# 10                        Cairo, Egypt                 Full Time
# 11               Tanta, Gharbia, Egypt   Full TimeWork From Home
# 12  10th of Ramadan City, Cairo, Egypt                 Full Time
# 13                        Cairo, Egypt                 Full Time
# 14                        Cairo, Egypt                 Full Time
#
#                                            job_skills
# 0   Experienced · 5 - 9 Yrs of Exp · IT/Software D...
# 1   Experienced · 3+ Yrs of Exp · IT/Software Deve...
# 2   Experienced · 2 - 4 Yrs of Exp · IT/Software D...
# 3   Experienced · 4 - 6 Yrs of Exp · R&D/Science ·...
# 4   Experienced · 1 - 4 Yrs of Exp · IT/Software D...
# 5   Entry Level · R&D/Science · Immunology · immun...
# 6   Experienced · 2 - 3 Yrs of Exp · Business Deve...
# 7   Student · 0 - 1 Yrs of Exp · IT/Software Devel...
# 8   Manager · 4 - 10 Yrs of Exp · Banking · IT/Sof...
# 9   Experienced · 4 - 6 Yrs of Exp · IT/Software D...
# 10  Experienced · 5+ Yrs of Exp · IT/Software Deve...
# 11  Entry Level · 2 - 4 Yrs of Exp · IT/Software D...
# 12  Entry Level · 2 - 3 Yrs of Exp · IT/Software D...
# 13  Experienced · 2 - 5 Yrs of Exp · Creative/Desi...
# 14  Experienced · 4 - 7 Yrs of Exp · Creative/Desi...

# %%
WUZZUF.to_csv('WUZZUF.csv',index=False)
